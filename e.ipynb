# %%
while('e' == 'e'):
    print('e')
# Out:
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# ...
